# %%
# !pip install pytube
# !pip install wget
# Out:
# Requirement already satisfied: pytube in c:\programdata\anaconda3\lib\site-packages (9.5.3)
# Collecting wget
#   Downloading https://files.pythonhosted.org/packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Arasy\AppData\Local\pip\Cache\wheels\40\15\30\7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
#   Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x0000003DA3527EB8>, 'Connection to files.pythonhosted.org timed out. (connect timeout=15)')': /packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip

# %%
# pip install pytube  (https://github.com/nficano/pytube)
# pip install bs4
# pip install urllib2

from pytube import YouTube as YT
#import urllib2
import requests
from random import randint
import time
import pickle
from datetime import datetime
from bs4 import BeautifulSoup as BS
import os
import re
import wget

# %%
def grabmp4(url):
    try :
        yt = YT(url)
        stream = yt.streams.first()
        namafile = re.sub(r'[\\/*?:"<>|]','',str(yt.title))+".mp4"
        if (os.path.exists(lokasi+'/'+namafile)):
            print("File",str(yt.title),"exists, skipping download")
        else:
            print("Downloading", yt.title)
        logfile.append(str(datetime.now())+ " Start downloading "+ str(yt.title))
        stream.download(lokasi)
        logfile.append(str(datetime.now())+ " Finish downloading "+ str(yt.title))
    except Exception as e:
        print("Cannot download", url," reason =", e)
        logfile.append(str(datetime.now())+ " Cannot download "+ url+ " reason = "+ str(e))
        
def getpdf(url):
    wget.download(url, bar=bar_thermometer)

def delay():
    #delaying
    jeda = randint(10,100)
    jeda = 1.0/jeda
    jeda = randint(0,2)+jeda
    time.sleep(jeda)
    print("Waiting... ",jeda, "seconds")
    logfile.append(str(datetime.now())+ " Delaying "+ str(jeda)+ " seconds")

# %%
#inisialisasi

listvideo = []
listpdf = []
logfile = []
logfile.append("Start at "+str(datetime.now()))
listofplaylist = [("https://www.youtube.com/playlist?list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo","Statistic101")]

for playlist,folderlok in listofplaylist:
    lokasi = os.getcwd()+'/'+folderlok
    if(not os.path.exists(lokasi)):
        os.makedirs(lokasi)
    laman = requests.session().get(playlist, timeout = 5).text
    links = BS(laman).find_all('a')

    for i in links :
        link = i['href']
        # get youtube video file
        if('youtube' in link or 'watch' in link):
            awal = link.find('&')
            link = link[:awal]
            if link[0] == '/':
                link = "https://www.youtube.com"+link
            if link not in listvideo:
                listvideo.append(link)
            print('add link ',link)
        # get pdf file
        if('.pdf' in link):
            listpdf.append(link)

    print('total %d links' % len(listvideo))
    
    for i in listvideo:
        grabmp4(i)
        delay()

    for i in listpdf:
        getpdf(i)
        delay()

    pickle.dump(logfile, open("log"+folderlok+".p", "wb"))
# Out:
# add link  https://www.youtube.com//www.youtube.com/uploa
# add link  https://accounts.google.com/ServiceLogin?service=youtube
# add link  https://www.youtube.com//support.google.com/youtube/answer/1738660?hl=i
# add link  https://www.youtube.com//support.google.com/youtube/answer/1738660?hl=e
# add link  https://www.youtube.com/redirect?event=channel_banner
# add link  https://www.youtube.com//support.google.com/youtube/answer/3046484?hl=i
# add link  https://www.youtube.com/watch?v=KbB0FjPg0mw
# add link  https://www.youtube.com/watch?v=KbB0FjPg0mw
# add link  https://accounts.google.com/ServiceLogin?service=youtube
# add link  https://www.youtube.com/watch?v=KbB0FjPg0mw
# add link  https://www.youtube.com/watch?v=KbB0FjPg0mw
# add link  https://www.youtube.com/watch?v=FJd_1H3rZGg
# add link  https://www.youtube.com/watch?v=FJd_1H3rZGg
# Waiting...  1.015625 seconds
# Downloading Lecture 4: Conditional Probability | Statistics 110
# Waiting...  2.0208333333333335 seconds
# Downloading Lecture 4: Conditional Probability | Statistics 110
# Waiting...  2.025 seconds
# Downloading Lecture 5: Conditioning Continued, Law of Total Probability | Statistics 110
# Waiting...  2.0185185185185186 seconds
# Downloading Lecture 5: Conditioning Continued, Law of Total Probability | Statistics 110
# Waiting...  1.024390243902439 seconds
# Downloading Lecture 6: Monty Hall, Simpson&#39;s Paradox | Statistics 110
# Waiting...  0.013513513513513514 seconds
# Downloading Lecture 6: Monty Hall, Simpson&#39;s Paradox | Statistics 110
# Waiting...  0.015384615384615385 seconds
# Downloading Lecture 7: Gambler&#39;s Ruin and Random Variables | Statistics 110
# Waiting...  1.0126582278481013 seconds
# Downloading Lecture 7: Gambler&#39;s Ruin and Random Variables | Statistics 110
# Waiting...  1.0104166666666667 seconds
# Downloading Lecture 8: Random Variables and Their Distributions | Statistics 110
# Waiting...  1.05 seconds
# Downloading Lecture 8: Random Variables and Their Distributions | Statistics 110
# Waiting...  1.0217391304347827 seconds
# Downloading Lecture 9: Expectation, Indicator Random Variables, Linearity | Statistics 110
# Waiting...  2.0172413793103448 seconds
# Downloading Lecture 9: Expectation, Indicator Random Variables, Linearity | Statistics 110
# Waiting...  1.0204081632653061 seconds
# Downloading Lecture 10: Expectation Continued | Statistics 110
# Waiting...  2.0121951219512195 seconds
# Downloading Lecture 10: Expectation Continued | Statistics 110
# Waiting...  0.017543859649122806 seconds
# Downloading Lecture 11: The Poisson distribution | Statistics 110
# Waiting...  0.07692307692307693 seconds
# Downloading Lecture 11: The Poisson distribution | Statistics 110
# Waiting...  2.0142857142857142 seconds
# Downloading Lecture 12: Discrete vs. Continuous, the Uniform | Statistics 110
# Waiting...  1.0169491525423728 seconds
# Downloading Lecture 12: Discrete vs. Continuous, the Uniform | Statistics 110
# Waiting...  1.0212765957446808 seconds
# Downloading Lecture 13: Normal distribution | Statistics 110
# Waiting...  1.0185185185185186 seconds
# Downloading Lecture 13: Normal distribution | Statistics 110
# Waiting...  0.041666666666666664 seconds
# Downloading Lecture 14: Location, Scale, and LOTUS | Statistics 110
# Waiting...  1.010752688172043 seconds
# Downloading Lecture 14: Location, Scale, and LOTUS | Statistics 110
# Waiting...  0.047619047619047616 seconds
# Downloading Lecture 15: Midterm Review | Statistics 110
# Waiting...  2.0232558139534884 seconds
# Downloading Lecture 15: Midterm Review | Statistics 110
# Waiting...  2.0123456790123457 seconds
# Downloading Lecture 16: Exponential Distribution | Statistics 110
# Waiting...  0.025 seconds
# Downloading Lecture 16: Exponential Distribution | Statistics 110
# Waiting...  0.012345679012345678 seconds
# Downloading Lecture 17: Moment Generating Functions | Statistics 110
# Waiting...  1.0158730158730158 seconds
# Downloading Lecture 17: Moment Generating Functions | Statistics 110
# Waiting...  0.043478260869565216 seconds
# Downloading Lecture 18: MGFs Continued | Statistics 110
# Waiting...  1.0476190476190477 seconds
# Downloading Lecture 18: MGFs Continued | Statistics 110
# Waiting...  0.07142857142857142 seconds
# Downloading Lecture 19: Joint, Conditional, and Marginal Distributions | Statistics 110
# Waiting...  1.01 seconds
# Downloading Lecture 19: Joint, Conditional, and Marginal Distributions | Statistics 110
# Waiting...  0.013157894736842105 seconds
# Downloading Lecture 20: Multinomial and Cauchy | Statistics 110
# Waiting...  0.0125 seconds
# Downloading Lecture 20: Multinomial and Cauchy | Statistics 110
# Waiting...  2.013333333333333 seconds
# Downloading Lecture 21: Covariance and Correlation | Statistics 110
# Waiting...  2.0285714285714285 seconds
# Downloading Lecture 21: Covariance and Correlation | Statistics 110
# Waiting...  1.0147058823529411 seconds
# Downloading Lecture 22: Transformations and Convolutions | Statistics 110
# Waiting...  0.01639344262295082 seconds
# Downloading Lecture 22: Transformations and Convolutions | Statistics 110
# Waiting...  2.021276595744681 seconds
# Downloading Lecture 23: Beta distribution | Statistics 110
# Waiting...  1.0128205128205128 seconds
# Downloading Lecture 23: Beta distribution | Statistics 110
# Waiting...  2.0232558139534884 seconds
# Downloading Lecture 24: Gamma distribution and Poisson process | Statistics 110
# Waiting...  1.0166666666666666 seconds
# Downloading Lecture 24: Gamma distribution and Poisson process | Statistics 110
# Waiting...  1.0526315789473684 seconds
# Downloading Lecture 25: Order Statistics and Conditional Expectation | Statistics 110
# Waiting...  0.010309278350515464 seconds
# Downloading Lecture 25: Order Statistics and Conditional Expectation | Statistics 110
# Waiting...  2.0144927536231885 seconds
# Downloading Lecture 26: Conditional Expectation Continued | Statistics 110
# Waiting...  1.0416666666666667 seconds
# Downloading Lecture 26: Conditional Expectation Continued | Statistics 110
# Waiting...  2.011764705882353 seconds
# Downloading Lecture 27: Conditional Expectation given an R.V. | Statistics 110
# Waiting...  0.038461538461538464 seconds
# Downloading Lecture 27: Conditional Expectation given an R.V. | Statistics 110
# Waiting...  0.014925373134328358 seconds
# Downloading Lecture 28: Inequalities | Statistics 110
# Waiting...  2.0105263157894737 seconds
# Downloading Lecture 28: Inequalities | Statistics 110
# Waiting...  2.1 seconds
# Downloading Lecture 29: Law of Large Numbers and Central Limit Theorem | Statistics 110
# Waiting...  0.01020408163265306 seconds
# Downloading Lecture 29: Law of Large Numbers and Central Limit Theorem | Statistics 110
# Waiting...  0.010101010101010102 seconds
# Downloading Lecture 30: Chi-Square, Student-t, Multivariate Normal | Statistics 110
# Waiting...  2.010204081632653 seconds
# Downloading Lecture 30: Chi-Square, Student-t, Multivariate Normal | Statistics 110
# Waiting...  2.0555555555555554 seconds
# Downloading Lecture 31: Markov Chains | Statistics 110
# Waiting...  0.024390243902439025 seconds
# Downloading Lecture 31: Markov Chains | Statistics 110
# Waiting...  0.011363636363636364 seconds
# Downloading Lecture 32: Markov Chains Continued | Statistics 110
# Waiting...  0.02 seconds
# Downloading Lecture 32: Markov Chains Continued | Statistics 110
# Waiting...  0.034482758620689655 seconds
# Downloading Lecture 33: Markov Chains Continued Further | Statistics 110
# Waiting...  1.0588235294117647 seconds
# Downloading Lecture 33: Markov Chains Continued Further | Statistics 110
# Waiting...  1.0769230769230769 seconds
# Downloading Lecture 34: A Look Ahead | Statistics 110
# Waiting...  1.0769230769230769 seconds
# Downloading Lecture 34: A Look Ahead | Statistics 110
# Waiting...  0.03225806451612903 seconds
# Downloading Joseph Blitzstein: &quot;The Soul of Statistics&quot; | Harvard Thinks Big 4
# Waiting...  2.0153846153846153 seconds
# Downloading Joseph Blitzstein: &quot;The Soul of Statistics&quot; | Harvard Thinks Big 4
# Waiting...  0.011627906976744186 seconds
# Cannot download https://www.youtube.com//www.youtube.com/yt/about/id  reason = regex pattern ((?:v=|\/)([0-9A-Za-z_-]{11}).*) had zero matches
# Waiting...  0.02564102564102564 seconds
# Cannot download https://www.youtube.com//www.youtube.com/yt/press/id  reason = regex pattern ((?:v=|\/)([0-9A-Za-z_-]{11}).*) had zero matches
# Waiting...  2.0136986301369864 seconds
# Cannot download https://www.youtube.com//www.youtube.com/yt/copyright/id  reason = regex pattern ((?:v=|\/)([0-9A-Za-z_-]{11}).*) had zero matches
# Waiting...  2.0112359550561796 seconds
# Cannot download https://www.youtube.com//www.youtube.com/yt/creators  reason = regex pattern ((?:v=|\/)([0-9A-Za-z_-]{11}).*) had zero matches
# Waiting...  0.03571428571428571 seconds
# Cannot download https://www.youtube.com//www.youtube.com/yt/advertise  reason = regex pattern ((?:v=|\/)([0-9A-Za-z_-]{11}).*) had zero matches
# Waiting...  0.037037037037037035 seconds
# Cannot download https://www.youtube.com//www.youtube.com/yt/dev/id  reason = regex pattern ((?:v=|\/)([0-9A-Za-z_-]{11}).*) had zero matches
# Waiting...  0.041666666666666664 seconds
# Cannot download https://www.youtube.com//www.youtube.com/yt/policyandsafety/id  reason = This video is unavailable.
# Waiting...  0.02631578947368421 seconds
# Cannot download https://www.youtube.com//support.google.com/youtube/?hl=i  reason = regex pattern ((?:v=|\/)([0-9A-Za-z_-]{11}).*) had zero matches
# Waiting...  1.0204081632653061 seconds
# Cannot download https://accounts.google.com/ServiceLogin?service=youtube  reason = This video is unavailable.
# Waiting...  1.0166666666666666 seconds

# %%
for link in links:
    print(link['href'])
# Out:
# /
# //www.youtube.com/upload
# /user/Harvard
# /user/Harvard/featured?disable_polymer=1
# /user/Harvard/videos?disable_polymer=1
# /user/Harvard/playlists?disable_polymer=1
# /user/Harvard/community?disable_polymer=1
# /user/Harvard/channels?disable_polymer=1
# /user/Harvard/about?disable_polymer=1
# /
# /feed/trending
# /feed/history
# /premium
# /channel/UC-9-kyTW8ZkZNDHQJ6FgpwQ
# /channel/UCEgdi0XIXXZ-qJOFPf4JSKw
# /gaming
# /channel/UCYfdidRxbB8Qhf0Nx7ioOYw
# /channel/UC4R8DWoMoI7CAwX8_LjQHig
# /channel/UCrpQ4p1Ql_hG8rKXIKM1MOQ
# /channel/UCzuqhhs6NWbgTzMuM09WKDQ
# /feed/guide_builder
# https://accounts.google.com/ServiceLogin?uilel=3&hl=id&passive=true&service=youtube&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Ffeature%3Dsign_in_promo%26next%3D%252Fplaylist%253Flist%253DPL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo%26hl%3Did%26action_handle_signin%3Dtrue%26app%3Ddesktop
# //support.google.com/youtube/answer/1738660?hl=id
# javascript:void(0)
# javascript:void(0)
# //support.google.com/youtube/answer/1738660?hl=en
# javascript:void(0)
# /redirect?event=channel_banner&redir_token=ePQV6uXfftrNiumOXrUDuoDzPSZ8MTU3NDQwMjg0NEAxNTc0MzE2NDQ0&q=http%3A%2F%2Fwww.twitter.com%2Fharvard
# /redirect?event=channel_banner&redir_token=ePQV6uXfftrNiumOXrUDuoDzPSZ8MTU3NDQwMjg0NEAxNTc0MzE2NDQ0&q=http%3A%2F%2Fwww.soundcloud.com%2Fharvard
# /redirect?event=channel_banner&redir_token=ePQV6uXfftrNiumOXrUDuoDzPSZ8MTU3NDQwMjg0NEAxNTc0MzE2NDQ0&q=http%3A%2F%2Fwww.facebook.com%2Fharvard
# /redirect?event=channel_banner&redir_token=ePQV6uXfftrNiumOXrUDuoDzPSZ8MTU3NDQwMjg0NEAxNTc0MzE2NDQ0&q=http%3A%2F%2Fwww.harvard.edu%2F%3Futm_source%3Dyoutube%26utm_medium%3Dsocial%26utm_campaign%3Dyoutube-channel
# /user/Harvard
# /user/Harvard
# //support.google.com/youtube/answer/3046484?hl=id
# /user/Harvard/featured?disable_polymer=1
# /user/Harvard/videos?disable_polymer=1
# /user/Harvard/playlists?disable_polymer=1
# /user/Harvard/community?disable_polymer=1
# /user/Harvard/channels?disable_polymer=1
# /user/Harvard/about?disable_polymer=1
# /watch?v=KbB0FjPg0mw&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo
# /user/Harvard
# /watch?v=KbB0FjPg0mw&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo
# https://accounts.google.com/ServiceLogin?uilel=3&hl=id&passive=true&service=youtube&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Ffeature%3D__FEATURE__%26next%3D%252Fplaylist%253Flist%253DPL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo%26hl%3Did%26action_handle_signin%3Dtrue%26app%3Ddesktop
# /watch?v=KbB0FjPg0mw&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=2&t=0s
# /watch?v=KbB0FjPg0mw&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=2&t=0s
# /user/Harvard
# /watch?v=FJd_1H3rZGg&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=3&t=0s
# /watch?v=FJd_1H3rZGg&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=3&t=0s
# /user/Harvard
# /watch?v=LZ5Wergp_PA&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=4&t=0s
# /watch?v=LZ5Wergp_PA&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=4&t=0s
# /user/Harvard
# /watch?v=P7NE4WF8j-Q&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=5&t=0s
# /watch?v=P7NE4WF8j-Q&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=5&t=0s
# /user/Harvard
# /watch?v=JzDvVgNDxo8&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=6&t=0s
# /watch?v=JzDvVgNDxo8&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=6&t=0s
# /user/Harvard
# /watch?v=fDcjhAKuhqQ&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=7&t=0s
# /watch?v=fDcjhAKuhqQ&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=7&t=0s
# /user/Harvard
# /watch?v=PNrqCdslGi4&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=8&t=0s
# /watch?v=PNrqCdslGi4&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=8&t=0s
# /user/Harvard
# /watch?v=k2BB0p8byGA&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=9&t=0s
# /watch?v=k2BB0p8byGA&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=9&t=0s
# /user/Harvard
# /watch?v=LX2q356N2rU&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=10&t=0s
# /watch?v=LX2q356N2rU&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=10&t=0s
# /user/Harvard
# /watch?v=P1fSFvhPf7Q&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=11&t=0s
# /watch?v=P1fSFvhPf7Q&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=11&t=0s
# /user/Harvard
# /watch?v=TD1N4hxqMzY&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=12&t=0s
# /watch?v=TD1N4hxqMzY&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=12&t=0s
# /user/Harvard
# /watch?v=Tci---bVs60&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=13&t=0s
# /watch?v=Tci---bVs60&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=13&t=0s
# /user/Harvard
# /watch?v=72QjzHnYvL0&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=14&t=0s
# /watch?v=72QjzHnYvL0&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=14&t=0s
# /user/Harvard
# /watch?v=9vp1Ll2NpRw&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=15&t=0s
# /watch?v=9vp1Ll2NpRw&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=15&t=0s
# /user/Harvard
# /watch?v=yFRZf81sB5k&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=16&t=0s
# /watch?v=yFRZf81sB5k&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=16&t=0s
# /user/Harvard
# /watch?v=bM6nFDjvEns&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=17&t=0s
# /watch?v=bM6nFDjvEns&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=17&t=0s
# /user/Harvard
# /watch?v=N8O6zd6vTZ8&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=18&t=0s
# /watch?v=N8O6zd6vTZ8&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=18&t=0s
# /user/Harvard
# /watch?v=tVDdx6xUOcs&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=19&t=0s
# /watch?v=tVDdx6xUOcs&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=19&t=0s
# /user/Harvard
# /watch?v=J70dP_AECzQ&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=20&t=0s
# /watch?v=J70dP_AECzQ&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=20&t=0s
# /user/Harvard
# /watch?v=xiVWNkQUqKk&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=21&t=0s
# /watch?v=xiVWNkQUqKk&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=21&t=0s
# /user/Harvard
# /watch?v=IujCYxtpszU&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=22&t=0s
# /watch?v=IujCYxtpszU&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=22&t=0s
# /user/Harvard
# /watch?v=yXwPUAIvFyg&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=23&t=0s
# /watch?v=yXwPUAIvFyg&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=23&t=0s
# /user/Harvard
# /watch?v=UZjlBQbV1KU&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=24&t=0s
# /watch?v=UZjlBQbV1KU&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=24&t=0s
# /user/Harvard
# /watch?v=Qjeswpm0cWY&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=25&t=0s
# /watch?v=Qjeswpm0cWY&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=25&t=0s
# /user/Harvard
# /watch?v=2LR5JYbhyjg&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=26&t=0s
# /watch?v=2LR5JYbhyjg&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=26&t=0s
# /user/Harvard
# /watch?v=PgawcWisb0I&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=27&t=0s
# /watch?v=PgawcWisb0I&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=27&t=0s
# /user/Harvard
# /watch?v=gjBvCiRt8QA&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=28&t=0s
# /watch?v=gjBvCiRt8QA&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=28&t=0s
# /user/Harvard
# /watch?v=UtXK_EQ3Pow&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=29&t=0s
# /watch?v=UtXK_EQ3Pow&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=29&t=0s
# /user/Harvard
# /watch?v=OprNqnHsVIA&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=30&t=0s
# /watch?v=OprNqnHsVIA&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=30&t=0s
# /user/Harvard
# /watch?v=MF-XSJOsGqw&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=31&t=0s
# /watch?v=MF-XSJOsGqw&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=31&t=0s
# /user/Harvard
# /watch?v=8AJPs3gvNlY&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=32&t=0s
# /watch?v=8AJPs3gvNlY&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=32&t=0s
# /user/Harvard
# /watch?v=aBGOyZv2pZE&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=33&t=0s
# /watch?v=aBGOyZv2pZE&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=33&t=0s
# /user/Harvard
# /watch?v=Q-pCzTpwPBU&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=34&t=0s
# /watch?v=Q-pCzTpwPBU&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=34&t=0s
# /user/Harvard
# /watch?v=ChS3K2O-h7o&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=35&t=0s
# /watch?v=ChS3K2O-h7o&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=35&t=0s
# /user/Harvard
# /watch?v=dzFf3r1yph8&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=36&t=0s
# /watch?v=dzFf3r1yph8&list=PL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo&index=36&t=0s
# /user/Harvard
# /
# /feed/history
# //www.youtube.com/yt/about/id/
# //www.youtube.com/yt/press/id/
# //www.youtube.com/yt/copyright/id/
# //www.youtube.com/yt/creators/
# //www.youtube.com/yt/advertise/
# //www.youtube.com/yt/dev/id/
# /t/terms
# https://www.google.com/intl/id/policies/privacy/
# //www.youtube.com/yt/policyandsafety/id/
# //support.google.com/youtube/?hl=id
# /testtube
# https://accounts.google.com/ServiceLogin?uilel=3&hl=id&passive=true&service=youtube&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Ffeature%3Dplaylist%26next%3D%252Fplaylist%253Flist%253DPL2SOU6wwxB0uwwH80KTQ6ht66KWxbzTIo%26hl%3Did%26action_handle_signin%3Dtrue%26app%3Ddesktop
